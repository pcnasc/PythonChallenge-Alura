# %% [markdown]
# Desafio:
#
# Criar um arquivo .txt a partir de uma lista de perguntas vindas de uma lista em Python [].
# Ler as perguntas desse arquivo .txt e salvá-las em uma lista Python
# Obter respostas de um LLM para cada uma.
# Salvar os resultados em um novo arquivo .csv
# Ler o arquivo .csv usando Pandas

# %%
# !pip install google-genai
# Out:
# Requirement already satisfied: google-genai in /opt/anaconda3/envs/py-latest/lib/python3.14/site-packages (1.73.1)
# Requirement already satisfied: anyio<5.0.0,>=4.8.0 in /opt/anaconda3/envs/py-latest/lib/python3.14/site-packages (from google-genai) (4.12.1)
# Requirement already satisfied: google-auth<3.0.0,>=2.48.1 in /opt/anaconda3/envs/py-latest/lib/python3.14/site-packages (from google-auth[requests]<3.0.0,>=2.48.1->google-genai) (2.49.2)
# Requirement already satisfied: httpx<1.0.0,>=0.28.1 in /opt/anaconda3/envs/py-latest/lib/python3.14/site-packages (from google-genai) (0.28.1)
# Requirement already satisfied: pydantic<3.0.0,>=2.9.0 in /opt/anaconda3/envs/py-latest/lib/python3.14/site-packages (from google-genai) (2.12.5)
# Requirement already satisfied: requests<3.0.0,>=2.28.1 in /opt/anaconda3/envs/py-latest/lib/python3.14/site-packages (from google-genai) (2.33.1)
# Requirement already satisfied: tenacity<9.2.0,>=8.2.3 in /opt/anaconda3/envs/py-latest/lib/python3.14/site-packages (from google-genai) (9.1.4)
# Requirement already satisfied: websockets<17.0,>=13.0.0 in /opt/anaconda3/envs/py-latest/lib/python3.14/site-packages (from google-genai) (16.0)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.14.0 in /opt/anaconda3/envs/py-latest/lib/python3.14/site-packages (from google-genai) (4.15.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /opt/anaconda3/envs/py-latest/lib/python3.14/site-packages (from google-genai) (1.9.0)
# Requirement already satisfied: sniffio in /opt/anaconda3/envs/py-latest/lib/python3.14/site-packages (from google-genai) (1.3.1)
# Requirement already satisfied: idna>=2.8 in /opt/anaconda3/envs/py-latest/lib/python3.14/site-packages (from anyio<5.0.0,>=4.8.0->google-genai) (3.11)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /opt/anaconda3/envs/py-latest/lib/python3.14/site-packages (from google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai) (0.4.2)
# Requirement already satisfied: cryptography>=38.0.3 in /opt/anaconda3/envs/py-latest/lib/python3.14/site-packages (from google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai) (46.0.7)
# Requirement already satisfied: certifi in /opt/anaconda3/envs/py-latest/lib/python3.14/site-packages (from httpx<1.0.0,>=0.28.1->google-genai) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in /opt/anaconda3/envs/py-latest/lib/python3.14/site-packages (from httpx<1.0.0,>=0.28.1->google-genai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /opt/anaconda3/envs/py-latest/lib/python3.14/site-packages (from httpcore==1.*->httpx<1.0.0,>=0.28.1->google-genai) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/anaconda3/envs/py-latest/lib/python3.14/site-packages (from pydantic<3.0.0,>=2.9.0->google-genai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /opt/anaconda3/envs/py-latest/lib/python3.14/site-packages (from pydantic<3.0.0,>=2.9.0->google-genai) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /opt/anaconda3/envs/py-latest/lib/python3.14/site-packages (from pydantic<3.0.0,>=2.9.0->google-genai) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/anaconda3/envs/py-latest/lib/python3.14/site-packages (from requests<3.0.0,>=2.28.1->google-genai) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.26 in /opt/anaconda3/envs/py-latest/lib/python3.14/site-packages (from requests<3.0.0,>=2.28.1->google-genai) (2.6.1)
# Requirement already satisfied: cffi>=2.0.0 in /opt/anaconda3/envs/py-latest/lib/python3.14/site-packages (from cryptography>=38.0.3->google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai) (2.0.0)
# Requirement already satisfied: pycparser in /opt/anaconda3/envs/py-latest/lib/python3.14/site-packages (from cffi>=2.0.0->cryptography>=38.0.3->google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai) (3.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /opt/anaconda3/envs/py-latest/lib/python3.14/site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai) (0.6.3)

# %%
from google import genai
client = genai.Client(api_key="AIzaSyAe8jjNhBEx6rF4oSF9B7dIltt3fhze1Mw")

# %%
# Etapa 1
questions_list = [
    "What is the compression ratio of the Bugatti Chiron's 8.0L quad-turbocharged W16 engine?",
    "What type of valve train system does the Honda K20 engine use?",
    "What is the difference between understeer and oversteer, and how does weight distribution affect each?",
    "How does a Limited-Slip Differential (LSD) differ from an open differential in torque distribution?",
    "What is the purpose of a harmonic balancer on a crankshaft, and what happens when it fails?"
]

with open("questions.txt", "w", encoding="utf-8") as file:
    for question in questions_list:
        file.write(question + "\n")

# %%
# Etapa 2
challenge_list = []

with open("questions.txt", "r", encoding="utf-8") as file:
    for line in file:
        challenge_list.append(line.strip())
    print(challenge_list)
# Out:
# ["What is the compression ratio of the Bugatti Chiron's 8.0L quad-turbocharged W16 engine?", 'What type of valve train system does the Honda K20 engine use?', 'What is the difference between understeer and oversteer, and how does weight distribution affect each?', 'How does a Limited-Slip Differential (LSD) differ from an open differential in torque distribution?', 'What is the purpose of a harmonic balancer on a crankshaft, and what happens when it fails?']

# %%
# Etapa 3
list_of_answers = []

for questions in challenge_list:
    answer = client.models.generate_content(
        model="gemini-2.5-flash",
        contents=f"generate a succinct answer for the question {questions}"
    )
    list_of_answers.append({"question": questions, "answer": answer.text})  # indented inside loop + fixed variable name

# %%
list_of_answers
# Out:
# [{'question': "What is the compression ratio of the Bugatti Chiron's 8.0L quad-turbocharged W16 engine?",
#   'answer': "The Bugatti Chiron's 8.0L quad-turbocharged W16 engine has a compression ratio of **9.0:1**."},
#  {'question': 'What type of valve train system does the Honda K20 engine use?',
#   'answer': 'Dual Overhead Cam (DOHC) with i-VTEC.'},
#  {'question': 'What is the difference between understeer and oversteer, and how does weight distribution affect each?',
#   'answer': '**Understeer** occurs when the **front wheels lose grip**, causing the car to turn less sharply than intended (it "plows" straight).\n*   **Weight Distribution Impact:** A **front-heavy** weight distribution makes a car more prone to understeer as the front tires are already carrying more load. Heavy braking or lifting off the throttle can transfer weight forward, potentially increasing front grip but unloading the rear, which *could* reduce understeer if the front has enough grip, or induce oversteer if the rear loses it first. However, *excessive static front load* makes the front tires reach their limit sooner.\n\n**Oversteer** occurs when the **rear wheels lose grip**, causing the rear of the car to slide out and turn more sharply than intended (it "fishtails").\n*   **Weight Distribution Impact:** A **rear-heavy** or **rear-light** (relative to the front\'s ability to grip) weight distribution, or significant weight transfer *to the front* (e.g., during hard braking or lifting off the throttle mid-corner), unloads the rear tires, making them more likely to lose traction and promote oversteer.\n\nIn essence, **understeer is front-end grip loss, oversteer is rear-end grip loss.**'},
#  {'question': 'How does a Limited-Slip Differential (LSD) differ from an open differential in torque distribution?',
#   'answer': 'An open differential distributes torque equally, meaning if one wheel loses traction, all power goes to that slipping wheel. A Limited-Slip Differential (LSD), however, limits this slip and actively **transfers a portion of the torque to the wheel with more traction**, ensuring power is still delivered to the ground.'},
#  {'question': 'What is the purpose of a harmonic balancer on a crankshaft, and what happens when it fails?',
#   'answer': "A harmonic balancer's purpose is to **dampen torsional (twisting) vibrations** on the crankshaft, protecting it, bearings, and other engine components from damage.\n\nWhen it fails, **excessive engine vibration** can occur, leading to accelerated wear or catastrophic failure of crankshaft bearings, the crankshaft itself, and can cause accessory belt issues."}]

# %%
import pandas as pd
df_questions_and_answers = pd.DataFrame(list_of_answers)
